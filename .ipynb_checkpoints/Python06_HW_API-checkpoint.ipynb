# %%
# Dependencies
from citipy import citipy
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openweathermapy as ow
import requests as req
import time
#from selenium.webdriver.common.keys import Ke
import random
import decimal
# %matplotlib inline

# %%
api_key="862e2d5f1fa11f589a0d6ca0acbd4cdb"

url="http://api.openweathermap.org/data/2.5/weather?lat=35&lon=139"
weather_response=req.get(url)
weather_json= weather_response.json()
query = url + "api-key=" + api_key 
investigate=req.get(url+ "&appid="+api_key).json()
investigate
# Out:
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 35, 'lon': 139},
#  'dt': 1509148800,
#  'id': 1851632,
#  'main': {'humidity': 82,
#   'pressure': 1026,
#   'temp': 290.15,
#   'temp_max': 290.15,
#   'temp_min': 290.15},
#  'name': 'Shuzenji',
#  'sys': {'country': 'JP',
#   'id': 7616,
#   'message': 0.1643,
#   'sunrise': 1509138059,
#   'sunset': 1509177244,
#   'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#    'icon': '10d',
#    'id': 500,
#    'main': 'Rain'}],
#  'wind': {'deg': 40, 'speed': 9.3}}

# %% [markdown]
# Create a pandas dataframe called location_data Set two columns in the data frame to be random numbers for both Latitude and Longitude Values

# %%
location_data = pd.DataFrame()
location_data['lat_values'] = [np.random.uniform(-90,90) for x in range(1500)]
location_data['lng_values'] = [np.random.uniform(-180, 180) for x in range(1500)]

location_data.head()#check
# Out:
#    lat_values  lng_values
# 0  -37.772357  -11.362772
# 1   88.400137 -172.652405
# 2  -48.354058   -3.086240
# 3   44.725651  -62.494576
# 4   47.626344  -54.124985

# %% [markdown]
# Create two more columns in location_data for city and country. Start your first for loop employing the citipy library to pic the city nearest to the previous created random values for latitude and longitude. Get both the city name and country code and put the values in the correct columns

# %%
location_data['city'] = ""
location_data['country'] = ""

count = 0
for index, row in location_data.iterrows():
    near_city = citipy.nearest_city(row['lat_values'], row['lng_values']).city_name
    near_country = citipy.nearest_city(row['lat_values'], row['lng_values']).country_code
    location_data.set_value(index,"city",near_city)
    location_data.set_value(index,"country",near_country)
location_data.head()#check
# Out:
#    lat_values  lng_values         city country
# 0  -37.772357  -11.362772    jamestown      sh
# 1   88.400137 -172.652405  mys shmidta      ru
# 2  -48.354058   -3.086240    cape town      za
# 3   44.725651  -62.494576  new glasgow      ca
# 4   47.626344  -54.124985  bay roberts      ca

# %% [markdown]
# Looking at sample size of location_data

# %%
len(location_data)
# Out:
# 1500

# %% [markdown]
# removing the duplicates of location_data based on city, and country values. Could have used unique.

# %%
location_data=location_data.drop_duplicates(['city','country'],keep = "first")
#.unique

# %% [markdown]
# Created Temperature, Humidity, Cloudiness, Wind Speed, Longitude (actual), and Latitude (actual) for location_data

# %%
location_data['Temp'] = ""
location_data['Humidity'] = ""
location_data['Cloudiness'] = ""
location_data['Wind Speed'] = ""
location_data["Lat"] =""
location_data["Longitude"] =""

# %% [markdown]
# Set my sample size, created the target_url variable, and picked what types of units these values will display in

# %%
# Set the sample size.
sample_size = 500

target_url = 'http://api.openweathermap.org/data/2.5/weather?q='
units = 'imperial'

# %%
location_data.head()#check
# Out:
#    lat_values  lng_values         city country Temp Humidity Cloudiness  \
# 0  -37.772357  -11.362772    jamestown      sh
# 1   88.400137 -172.652405  mys shmidta      ru
# 2  -48.354058   -3.086240    cape town      za
# 3   44.725651  -62.494576  new glasgow      ca
# 4   47.626344  -54.124985  bay roberts      ca
#
#   Wind Speed Lat Longitude
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Performed API calls

# %%
record = 0
for index, row in location_data.iterrows():
    city_name = row['city']
    country_code = row['country']
    url = target_url + city_name + ',' + country_code + '&units=' + units + '&APPID=' + api_key
    print (url)
    try: 
        weather_response = req.get(url)
        weather_json = weather_response.json()
        latitude = weather_json["coord"]["lat"]
        longitude = weather_json["coord"]["lon"]
        temp = weather_json["main"]["temp"]
        humidity = weather_json["main"]["humidity"]
        cloud = weather_json["clouds"]["all"]
        wind = weather_json["wind"]["speed"]
        location_data.set_value(index,"Temp", temp)
        location_data.set_value(index,"Humidity",humidity)
        location_data.set_value(index,"Wind Speed", wind)
        location_data.set_value(index,"Cloudiness",cloud)
        location_data.set_value(index,"Lat", latitude)
        location_data.set_value(index,"Longitude",longitude)
        print("Retrieved data for %s, %s" % (city_name, country_code))
    except:
        print("No data for %s, %s" % (city_name,country_code))
    record += 1
    if record % 59 == 0:
        time.sleep(60)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for jamestown, sh
# http://api.openweathermap.org/data/2.5/weather?q=mys shmidta,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mys shmidta, ru
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for cape town, za
# http://api.openweathermap.org/data/2.5/weather?q=new glasgow,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for new glasgow, ca
# http://api.openweathermap.org/data/2.5/weather?q=bay roberts,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bay roberts, ca
# http://api.openweathermap.org/data/2.5/weather?q=thompson,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for thompson, ca
# http://api.openweathermap.org/data/2.5/weather?q=sinnamary,gf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for sinnamary, gf
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for arraial do cabo, br
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for busselton, au
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for rikitea, pf
# http://api.openweathermap.org/data/2.5/weather?q=puerto escondido,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for puerto escondido, mx
# http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for avarua, ck
# http://api.openweathermap.org/data/2.5/weather?q=hasaki,jp&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hasaki, jp
# http://api.openweathermap.org/data/2.5/weather?q=ust-uda,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ust-uda, ru
# http://api.openweathermap.org/data/2.5/weather?q=guicheng,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for guicheng, cn
# http://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for vaini, to
# http://api.openweathermap.org/data/2.5/weather?q=lebu,cl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lebu, cl
# http://api.openweathermap.org/data/2.5/weather?q=camocim,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for camocim, br
# http://api.openweathermap.org/data/2.5/weather?q=zaria,ng&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for zaria, ng
# http://api.openweathermap.org/data/2.5/weather?q=kaeo,nz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kaeo, nz
# http://api.openweathermap.org/data/2.5/weather?q=barrow,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for barrow, us
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe,cv&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for sao filipe, cv
# http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kapaa, us
# http://api.openweathermap.org/data/2.5/weather?q=okhotsk,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for okhotsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bredasdorp, za
# http://api.openweathermap.org/data/2.5/weather?q=megion,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for megion, ru
# http://api.openweathermap.org/data/2.5/weather?q=chapais,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for chapais, ca
# http://api.openweathermap.org/data/2.5/weather?q=constitucion,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for constitucion, mx
# http://api.openweathermap.org/data/2.5/weather?q=te anau,nz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for te anau, nz
# http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bluff, nz
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hobart, au
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for albany, au
# http://api.openweathermap.org/data/2.5/weather?q=lompoc,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lompoc, us
# http://api.openweathermap.org/data/2.5/weather?q=mataura,pf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mataura, pf
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for port elizabeth, za
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hithadhoo, mv
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for atuona, pf
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for carnarvon, au
# http://api.openweathermap.org/data/2.5/weather?q=san benito,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for san benito, us
# http://api.openweathermap.org/data/2.5/weather?q=pochutla,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for pochutla, mx
# http://api.openweathermap.org/data/2.5/weather?q=kamina,cd&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kamina, cd
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ushuaia, ar
# http://api.openweathermap.org/data/2.5/weather?q=tiksi,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tiksi, ru
# http://api.openweathermap.org/data/2.5/weather?q=vardo,no&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for vardo, no
# http://api.openweathermap.org/data/2.5/weather?q=pirgos,gr&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for pirgos, gr
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for belushya guba, ru
# http://api.openweathermap.org/data/2.5/weather?q=bolungarvik,is&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bolungarvik, is
# http://api.openweathermap.org/data/2.5/weather?q=veraval,in&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for veraval, in
# http://api.openweathermap.org/data/2.5/weather?q=cleethorpes,gb&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for cleethorpes, gb
# http://api.openweathermap.org/data/2.5/weather?q=warqla,dz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for warqla, dz
# http://api.openweathermap.org/data/2.5/weather?q=severnyy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for severnyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=esso,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for esso, ru
# http://api.openweathermap.org/data/2.5/weather?q=bogo,cm&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bogo, cm
# http://api.openweathermap.org/data/2.5/weather?q=zeya,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for zeya, ru
# http://api.openweathermap.org/data/2.5/weather?q=satitoa,ws&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for satitoa, ws
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro,mg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for taolanaro, mg
# http://api.openweathermap.org/data/2.5/weather?q=beyneu,kz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for beyneu, kz
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane,es&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for los llanos de aridane, es
# http://api.openweathermap.org/data/2.5/weather?q=ulaangom,mn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ulaangom, mn
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for severo-kurilsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=opuwo,na&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for opuwo, na
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik,fo&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for klaksvik, fo
# http://api.openweathermap.org/data/2.5/weather?q=saint george,bm&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for saint george, bm
# http://api.openweathermap.org/data/2.5/weather?q=norman wells,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for norman wells, ca
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bambous virieux, mu
# http://api.openweathermap.org/data/2.5/weather?q=tumannyy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tumannyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=hamilton,bm&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hamilton, bm
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for sentyabrskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=houston,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for houston, ca
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ribeira grande, pt
# http://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for upernavik, gl
# http://api.openweathermap.org/data/2.5/weather?q=sindor,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for sindor, ru
# http://api.openweathermap.org/data/2.5/weather?q=benguela,ao&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for benguela, ao
# http://api.openweathermap.org/data/2.5/weather?q=quatre cocos,mu&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for quatre cocos, mu
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tuktoyaktuk, ca
# http://api.openweathermap.org/data/2.5/weather?q=tartagal,ar&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tartagal, ar
# http://api.openweathermap.org/data/2.5/weather?q=paucartambo,pe&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for paucartambo, pe
# http://api.openweathermap.org/data/2.5/weather?q=mount gambier,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mount gambier, au
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for punta arenas, cl
# http://api.openweathermap.org/data/2.5/weather?q=sorland,no&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for sorland, no
# http://api.openweathermap.org/data/2.5/weather?q=port-cartier,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for port-cartier, ca
# http://api.openweathermap.org/data/2.5/weather?q=bac lieu,vn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bac lieu, vn
# http://api.openweathermap.org/data/2.5/weather?q=port lincoln,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for port lincoln, au
# http://api.openweathermap.org/data/2.5/weather?q=kamaishi,jp&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kamaishi, jp
# http://api.openweathermap.org/data/2.5/weather?q=goma,cd&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for goma, cd
# http://api.openweathermap.org/data/2.5/weather?q=goito,it&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for goito, it
# http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for dikson, ru
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for saint-philippe, re
# http://api.openweathermap.org/data/2.5/weather?q=mezhdurechensk,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mezhdurechensk, ru
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for attawapiskat, ca
# http://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hermanus, za
# http://api.openweathermap.org/data/2.5/weather?q=samarai,pg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for samarai, pg
# http://api.openweathermap.org/data/2.5/weather?q=eyl,so&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for eyl, so
# http://api.openweathermap.org/data/2.5/weather?q=olinda,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for olinda, br
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bengkulu, id
# http://api.openweathermap.org/data/2.5/weather?q=husavik,is&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for husavik, is
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe,mg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tsihombe, mg
# http://api.openweathermap.org/data/2.5/weather?q=genhe,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for genhe, cn
# http://api.openweathermap.org/data/2.5/weather?q=codrington,ag&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for codrington, ag
# http://api.openweathermap.org/data/2.5/weather?q=bosaso,so&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bosaso, so
# http://api.openweathermap.org/data/2.5/weather?q=long branch,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for long branch, us
# http://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for provideniya, ru
# http://api.openweathermap.org/data/2.5/weather?q=dingle,ie&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for dingle, ie
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for yellowknife, ca
# http://api.openweathermap.org/data/2.5/weather?q=yabelo,et&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for yabelo, et
# http://api.openweathermap.org/data/2.5/weather?q=tambura,sd&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# No data for tambura, sd
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ilulissat, gl
# http://api.openweathermap.org/data/2.5/weather?q=patiya,bd&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for patiya, bd
# http://api.openweathermap.org/data/2.5/weather?q=mataram,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mataram, id
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for illoqqortoormiut, gl
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu,wf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for vaitupu, wf
# http://api.openweathermap.org/data/2.5/weather?q=zalantun,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for zalantun, cn
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for new norfolk, au
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg,sj&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# No data for barentsburg, sj
# http://api.openweathermap.org/data/2.5/weather?q=bandarbeyla,so&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bandarbeyla, so
# http://api.openweathermap.org/data/2.5/weather?q=bonavista,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bonavista, ca
# http://api.openweathermap.org/data/2.5/weather?q=salvador,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for salvador, br
# http://api.openweathermap.org/data/2.5/weather?q=samusu,ws&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for samusu, ws
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for puerto ayora, ec
# http://api.openweathermap.org/data/2.5/weather?q=itarema,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for itarema, br
# http://api.openweathermap.org/data/2.5/weather?q=carauari,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for carauari, br
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kruisfontein, za
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for komsomolskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=prince rupert,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for prince rupert, ca
# http://api.openweathermap.org/data/2.5/weather?q=viedma,ar&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for viedma, ar
# http://api.openweathermap.org/data/2.5/weather?q=madison,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for madison, us
# http://api.openweathermap.org/data/2.5/weather?q=doka,sd&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for doka, sd
# http://api.openweathermap.org/data/2.5/weather?q=castro,cl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for castro, cl
# http://api.openweathermap.org/data/2.5/weather?q=tura,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tura, ru
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for saskylakh, ru
# http://api.openweathermap.org/data/2.5/weather?q=camargo,bo&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for camargo, bo
# http://api.openweathermap.org/data/2.5/weather?q=udachnyy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for udachnyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=muros,es&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for muros, es
# http://api.openweathermap.org/data/2.5/weather?q=chuy,uy&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for chuy, uy
# http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for butaritari, ki
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for cabo san lucas, mx
# http://api.openweathermap.org/data/2.5/weather?q=anar darreh,af&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for anar darreh, af
# http://api.openweathermap.org/data/2.5/weather?q=tazmalt,dz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tazmalt, dz
# http://api.openweathermap.org/data/2.5/weather?q=asfi,ma&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for asfi, ma
# http://api.openweathermap.org/data/2.5/weather?q=esperance,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for esperance, au
# http://api.openweathermap.org/data/2.5/weather?q=povenets,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for povenets, ru
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg,mu&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mahebourg, mu
# http://api.openweathermap.org/data/2.5/weather?q=east london,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for east london, za
# http://api.openweathermap.org/data/2.5/weather?q=souillac,mu&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for souillac, mu
# http://api.openweathermap.org/data/2.5/weather?q=xining,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for xining, cn
# http://api.openweathermap.org/data/2.5/weather?q=manokwari,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for manokwari, id
# http://api.openweathermap.org/data/2.5/weather?q=marechal candido rondon,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for marechal candido rondon, br
# http://api.openweathermap.org/data/2.5/weather?q=yomitan,jp&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for yomitan, jp
# http://api.openweathermap.org/data/2.5/weather?q=kiama,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kiama, au
# http://api.openweathermap.org/data/2.5/weather?q=guapi,co&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for guapi, co
# http://api.openweathermap.org/data/2.5/weather?q=bossangoa,cf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bossangoa, cf
# http://api.openweathermap.org/data/2.5/weather?q=onguday,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for onguday, ru
# http://api.openweathermap.org/data/2.5/weather?q=decatur,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for decatur, us
# http://api.openweathermap.org/data/2.5/weather?q=laguna,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for laguna, br
# http://api.openweathermap.org/data/2.5/weather?q=zhangjiakou,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for zhangjiakou, cn
# http://api.openweathermap.org/data/2.5/weather?q=tidore,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tidore, id
# http://api.openweathermap.org/data/2.5/weather?q=chumikan,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for chumikan, ru
# http://api.openweathermap.org/data/2.5/weather?q=nioro,ml&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nioro, ml
# http://api.openweathermap.org/data/2.5/weather?q=revelstoke,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for revelstoke, ca
# http://api.openweathermap.org/data/2.5/weather?q=ulladulla,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ulladulla, au
# http://api.openweathermap.org/data/2.5/weather?q=paragominas,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for paragominas, br
# http://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for luderitz, na
# http://api.openweathermap.org/data/2.5/weather?q=usinsk,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for usinsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=tilichiki,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tilichiki, ru
# http://api.openweathermap.org/data/2.5/weather?q=qandahar,af&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for qandahar, af
# http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for port alfred, za
# http://api.openweathermap.org/data/2.5/weather?q=marzuq,ly&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for marzuq, ly
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen,sj&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for longyearbyen, sj
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nikolskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=bonfim,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bonfim, br
# http://api.openweathermap.org/data/2.5/weather?q=krasnoselkup,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for krasnoselkup, ru
# http://api.openweathermap.org/data/2.5/weather?q=carmen,ph&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for carmen, ph
# http://api.openweathermap.org/data/2.5/weather?q=kodiak,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kodiak, us
# http://api.openweathermap.org/data/2.5/weather?q=atar,mr&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for atar, mr
# http://api.openweathermap.org/data/2.5/weather?q=griffith,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for griffith, au
# http://api.openweathermap.org/data/2.5/weather?q=magaria,ne&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for magaria, ne
# http://api.openweathermap.org/data/2.5/weather?q=labytnangi,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for labytnangi, ru
# http://api.openweathermap.org/data/2.5/weather?q=coihueco,cl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for coihueco, cl
# http://api.openweathermap.org/data/2.5/weather?q=lock haven,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lock haven, us
# http://api.openweathermap.org/data/2.5/weather?q=northam,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for northam, au
# http://api.openweathermap.org/data/2.5/weather?q=saint-ambroise,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for saint-ambroise, ca
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nizhneyansk, ru
# http://api.openweathermap.org/data/2.5/weather?q=torredonjimeno,es&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for torredonjimeno, es
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for qaanaaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=paradwip,in&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for paradwip, in
# http://api.openweathermap.org/data/2.5/weather?q=townsville,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for townsville, au
# http://api.openweathermap.org/data/2.5/weather?q=nizwa,om&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nizwa, om
# http://api.openweathermap.org/data/2.5/weather?q=louisbourg,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for louisbourg, ca
# http://api.openweathermap.org/data/2.5/weather?q=antalaha,mg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for antalaha, mg
# http://api.openweathermap.org/data/2.5/weather?q=kemijarvi,fi&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kemijarvi, fi
# http://api.openweathermap.org/data/2.5/weather?q=kavieng,pg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kavieng, pg
# http://api.openweathermap.org/data/2.5/weather?q=vao,nc&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for vao, nc
# http://api.openweathermap.org/data/2.5/weather?q=garbolovo,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for garbolovo, ru
# http://api.openweathermap.org/data/2.5/weather?q=flinders,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for flinders, au
# http://api.openweathermap.org/data/2.5/weather?q=saint-augustin,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for saint-augustin, ca
# http://api.openweathermap.org/data/2.5/weather?q=praia da vitoria,pt&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for praia da vitoria, pt
# http://api.openweathermap.org/data/2.5/weather?q=takanabe,jp&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for takanabe, jp
# http://api.openweathermap.org/data/2.5/weather?q=oleksandrivka,ua&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for oleksandrivka, ua
# http://api.openweathermap.org/data/2.5/weather?q=deputatskiy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for deputatskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=ascension,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ascension, mx
# http://api.openweathermap.org/data/2.5/weather?q=phan thiet,vn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for phan thiet, vn
# http://api.openweathermap.org/data/2.5/weather?q=maniitsoq,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for maniitsoq, gl
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nanortalik, gl
# http://api.openweathermap.org/data/2.5/weather?q=beloha,mg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for beloha, mg
# http://api.openweathermap.org/data/2.5/weather?q=aleksandrovskiy zavod,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for aleksandrovskiy zavod, ru
# http://api.openweathermap.org/data/2.5/weather?q=torbay,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for torbay, ca
# http://api.openweathermap.org/data/2.5/weather?q=axim,gh&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for axim, gh
# http://api.openweathermap.org/data/2.5/weather?q=northport,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for northport, us
# http://api.openweathermap.org/data/2.5/weather?q=angoram,pg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for angoram, pg
# http://api.openweathermap.org/data/2.5/weather?q=tahe,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tahe, cn
# http://api.openweathermap.org/data/2.5/weather?q=avera,pf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for avera, pf
# http://api.openweathermap.org/data/2.5/weather?q=waipawa,nz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for waipawa, nz
# http://api.openweathermap.org/data/2.5/weather?q=doha,kw&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for doha, kw
# http://api.openweathermap.org/data/2.5/weather?q=lalin,es&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lalin, es
# http://api.openweathermap.org/data/2.5/weather?q=texarkana,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for texarkana, us
# http://api.openweathermap.org/data/2.5/weather?q=ryotsu,jp&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ryotsu, jp
# http://api.openweathermap.org/data/2.5/weather?q=alice springs,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for alice springs, au
# http://api.openweathermap.org/data/2.5/weather?q=manaure,co&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for manaure, co
# http://api.openweathermap.org/data/2.5/weather?q=jacareacanga,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for jacareacanga, br
# http://api.openweathermap.org/data/2.5/weather?q=sakaiminato,jp&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for sakaiminato, jp
# http://api.openweathermap.org/data/2.5/weather?q=eureka,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for eureka, us
# http://api.openweathermap.org/data/2.5/weather?q=airai,pw&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for airai, pw
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo,cl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for coquimbo, cl
# http://api.openweathermap.org/data/2.5/weather?q=vila velha,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for vila velha, br
# http://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for georgetown, sh
# http://api.openweathermap.org/data/2.5/weather?q=kuruman,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kuruman, za
# http://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for khatanga, ru
# http://api.openweathermap.org/data/2.5/weather?q=san juan,hn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for san juan, hn
# http://api.openweathermap.org/data/2.5/weather?q=manali,in&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for manali, in
# http://api.openweathermap.org/data/2.5/weather?q=talnakh,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for talnakh, ru
# http://api.openweathermap.org/data/2.5/weather?q=isabela,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for isabela, us
# http://api.openweathermap.org/data/2.5/weather?q=toliary,mg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for toliary, mg
# http://api.openweathermap.org/data/2.5/weather?q=kulhudhuffushi,mv&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kulhudhuffushi, mv
# http://api.openweathermap.org/data/2.5/weather?q=kerchevskiy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kerchevskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ostrovnoy, ru
# http://api.openweathermap.org/data/2.5/weather?q=tautira,pf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tautira, pf
# http://api.openweathermap.org/data/2.5/weather?q=phumi samraong,kh&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for phumi samraong, kh
# http://api.openweathermap.org/data/2.5/weather?q=padang,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for padang, id
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for leningradskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=namtsy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for namtsy, ru
# http://api.openweathermap.org/data/2.5/weather?q=tubruq,ly&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tubruq, ly
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for beringovskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=mocuba,mz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mocuba, mz
# http://api.openweathermap.org/data/2.5/weather?q=hilo,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hilo, us
# http://api.openweathermap.org/data/2.5/weather?q=estancia,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for estancia, br
# http://api.openweathermap.org/data/2.5/weather?q=antofagasta,cl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for antofagasta, cl
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lavrentiya, ru
# http://api.openweathermap.org/data/2.5/weather?q=ruatoria,nz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ruatoria, nz
# http://api.openweathermap.org/data/2.5/weather?q=ottawa,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ottawa, us
# http://api.openweathermap.org/data/2.5/weather?q=tacuarembo,uy&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tacuarembo, uy
# http://api.openweathermap.org/data/2.5/weather?q=morondava,mg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for morondava, mg
# http://api.openweathermap.org/data/2.5/weather?q=geraldton,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for geraldton, au
# http://api.openweathermap.org/data/2.5/weather?q=abengourou,ci&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for abengourou, ci
# http://api.openweathermap.org/data/2.5/weather?q=sao felix do xingu,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for sao felix do xingu, br
# http://api.openweathermap.org/data/2.5/weather?q=vicuna,cl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for vicuna, cl
# http://api.openweathermap.org/data/2.5/weather?q=bubaque,gw&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bubaque, gw
# http://api.openweathermap.org/data/2.5/weather?q=ayan,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ayan, ru
# http://api.openweathermap.org/data/2.5/weather?q=grand-santi,gf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for grand-santi, gf
# http://api.openweathermap.org/data/2.5/weather?q=margate,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for margate, za
# http://api.openweathermap.org/data/2.5/weather?q=rocha,uy&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for rocha, uy
# http://api.openweathermap.org/data/2.5/weather?q=acopiara,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for acopiara, br
# http://api.openweathermap.org/data/2.5/weather?q=lasa,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lasa, cn
# http://api.openweathermap.org/data/2.5/weather?q=turukhansk,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for turukhansk, ru
# http://api.openweathermap.org/data/2.5/weather?q=rojhan,pk&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for rojhan, pk
# http://api.openweathermap.org/data/2.5/weather?q=sitka,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for sitka, us
# http://api.openweathermap.org/data/2.5/weather?q=eskasem,af&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for eskasem, af
# http://api.openweathermap.org/data/2.5/weather?q=nyuksenitsa,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nyuksenitsa, ru
# http://api.openweathermap.org/data/2.5/weather?q=bluefield,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bluefield, us
# http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for palabuhanratu, id
# http://api.openweathermap.org/data/2.5/weather?q=port keats,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for port keats, au
# http://api.openweathermap.org/data/2.5/weather?q=paamiut,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for paamiut, gl
# http://api.openweathermap.org/data/2.5/weather?q=berlevag,no&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for berlevag, no
# http://api.openweathermap.org/data/2.5/weather?q=hofn,is&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hofn, is
# http://api.openweathermap.org/data/2.5/weather?q=ketchikan,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ketchikan, us
# http://api.openweathermap.org/data/2.5/weather?q=beira,mz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for beira, mz
# http://api.openweathermap.org/data/2.5/weather?q=lorengau,pg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lorengau, pg
# http://api.openweathermap.org/data/2.5/weather?q=aporawan,ph&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for aporawan, ph
# http://api.openweathermap.org/data/2.5/weather?q=toyos,hn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for toyos, hn
# http://api.openweathermap.org/data/2.5/weather?q=chandbali,in&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for chandbali, in
# http://api.openweathermap.org/data/2.5/weather?q=magistralnyy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for magistralnyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=ancud,cl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ancud, cl
# http://api.openweathermap.org/data/2.5/weather?q=delhi,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for delhi, ca
# http://api.openweathermap.org/data/2.5/weather?q=dillon,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for dillon, us
# http://api.openweathermap.org/data/2.5/weather?q=kampot,kh&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kampot, kh
# http://api.openweathermap.org/data/2.5/weather?q=zetel,de&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for zetel, de
# http://api.openweathermap.org/data/2.5/weather?q=montepuez,mz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for montepuez, mz
# http://api.openweathermap.org/data/2.5/weather?q=juazeiro,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for juazeiro, br
# http://api.openweathermap.org/data/2.5/weather?q=huarmey,pe&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for huarmey, pe
# http://api.openweathermap.org/data/2.5/weather?q=harper,lr&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for harper, lr
# http://api.openweathermap.org/data/2.5/weather?q=qasigiannguit,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for qasigiannguit, gl
# http://api.openweathermap.org/data/2.5/weather?q=jurm,af&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for jurm, af
# http://api.openweathermap.org/data/2.5/weather?q=faya,td&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for faya, td
# http://api.openweathermap.org/data/2.5/weather?q=bethel,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bethel, us
# http://api.openweathermap.org/data/2.5/weather?q=liverpool,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for liverpool, ca
# http://api.openweathermap.org/data/2.5/weather?q=marsa matruh,eg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for marsa matruh, eg
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for fairbanks, us
# http://api.openweathermap.org/data/2.5/weather?q=ongandjera,na&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ongandjera, na
# http://api.openweathermap.org/data/2.5/weather?q=carutapera,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for carutapera, br
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tasiilaq, gl
# http://api.openweathermap.org/data/2.5/weather?q=hilton head island,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hilton head island, us
# http://api.openweathermap.org/data/2.5/weather?q=tunxi,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tunxi, cn
# http://api.openweathermap.org/data/2.5/weather?q=pevek,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for pevek, ru
# http://api.openweathermap.org/data/2.5/weather?q=cabedelo,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for cabedelo, br
# http://api.openweathermap.org/data/2.5/weather?q=kungurtug,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kungurtug, ru
# http://api.openweathermap.org/data/2.5/weather?q=umzimvubu,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for umzimvubu, za
# http://api.openweathermap.org/data/2.5/weather?q=la rioja,ar&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for la rioja, ar
# http://api.openweathermap.org/data/2.5/weather?q=abu dhabi,ae&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for abu dhabi, ae
# http://api.openweathermap.org/data/2.5/weather?q=price,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for price, us
# http://api.openweathermap.org/data/2.5/weather?q=mandalgovi,mn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mandalgovi, mn
# http://api.openweathermap.org/data/2.5/weather?q=bonanza,ni&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bonanza, ni
# http://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for acapulco, mx
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for guerrero negro, mx
# http://api.openweathermap.org/data/2.5/weather?q=atocha,bo&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for atocha, bo
# http://api.openweathermap.org/data/2.5/weather?q=fort nelson,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for fort nelson, ca
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata,nz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kaitangata, nz
# http://api.openweathermap.org/data/2.5/weather?q=taoudenni,ml&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for taoudenni, ml
# http://api.openweathermap.org/data/2.5/weather?q=kintampo,gh&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kintampo, gh
# http://api.openweathermap.org/data/2.5/weather?q=samalaeulu,ws&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for samalaeulu, ws
# http://api.openweathermap.org/data/2.5/weather?q=saldanha,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for saldanha, za
# http://api.openweathermap.org/data/2.5/weather?q=crotone,it&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for crotone, it
# http://api.openweathermap.org/data/2.5/weather?q=shenjiamen,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for shenjiamen, cn
# http://api.openweathermap.org/data/2.5/weather?q=mukhanovo,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mukhanovo, ru
# http://api.openweathermap.org/data/2.5/weather?q=sidi ali,dz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for sidi ali, dz
# http://api.openweathermap.org/data/2.5/weather?q=nata,bw&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nata, bw
# ...
# http://api.openweathermap.org/data/2.5/weather?q=yenagoa,ng&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for yenagoa, ng
# http://api.openweathermap.org/data/2.5/weather?q=salo,fi&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for salo, fi
# http://api.openweathermap.org/data/2.5/weather?q=touros,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for touros, br
# http://api.openweathermap.org/data/2.5/weather?q=tazovskiy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tazovskiy, ru
# http://api.openweathermap.org/data/2.5/weather?q=pionki,pl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for pionki, pl
# http://api.openweathermap.org/data/2.5/weather?q=arman,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for arman, ru
# http://api.openweathermap.org/data/2.5/weather?q=svetlogorsk,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for svetlogorsk, ru
# http://api.openweathermap.org/data/2.5/weather?q=felipe carrillo puerto,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for felipe carrillo puerto, mx
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik,is&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for olafsvik, is
# http://api.openweathermap.org/data/2.5/weather?q=pinar del rio,cu&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for pinar del rio, cu
# http://api.openweathermap.org/data/2.5/weather?q=amahai,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for amahai, id
# http://api.openweathermap.org/data/2.5/weather?q=milledgeville,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for milledgeville, us
# http://api.openweathermap.org/data/2.5/weather?q=jeremie,ht&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for jeremie, ht
# http://api.openweathermap.org/data/2.5/weather?q=mechetinskaya,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mechetinskaya, ru
# http://api.openweathermap.org/data/2.5/weather?q=kizilskoye,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kizilskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=casa nova,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for casa nova, br
# http://api.openweathermap.org/data/2.5/weather?q=kutum,sd&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kutum, sd
# http://api.openweathermap.org/data/2.5/weather?q=kletnya,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kletnya, ru
# http://api.openweathermap.org/data/2.5/weather?q=solok,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for solok, id
# http://api.openweathermap.org/data/2.5/weather?q=nouadhibou,mr&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nouadhibou, mr
# http://api.openweathermap.org/data/2.5/weather?q=kasongo-lunda,cd&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kasongo-lunda, cd
# http://api.openweathermap.org/data/2.5/weather?q=valparaiso,cl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for valparaiso, cl
# http://api.openweathermap.org/data/2.5/weather?q=hovd,mn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hovd, mn
# http://api.openweathermap.org/data/2.5/weather?q=cidreira,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for cidreira, br
# http://api.openweathermap.org/data/2.5/weather?q=salalah,om&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for salalah, om
# http://api.openweathermap.org/data/2.5/weather?q=ngunguru,nz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ngunguru, nz
# http://api.openweathermap.org/data/2.5/weather?q=labuhan,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for labuhan, id
# http://api.openweathermap.org/data/2.5/weather?q=osypenko,ua&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for osypenko, ua
# http://api.openweathermap.org/data/2.5/weather?q=hurghada,eg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hurghada, eg
# http://api.openweathermap.org/data/2.5/weather?q=chany,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for chany, ru
# http://api.openweathermap.org/data/2.5/weather?q=samana,do&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for samana, do
# http://api.openweathermap.org/data/2.5/weather?q=shiyan,cn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for shiyan, cn
# http://api.openweathermap.org/data/2.5/weather?q=bur gabo,so&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bur gabo, so
# http://api.openweathermap.org/data/2.5/weather?q=mezen,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mezen, ru
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east,mu&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for grand river south east, mu
# http://api.openweathermap.org/data/2.5/weather?q=summerside,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for summerside, ca
# http://api.openweathermap.org/data/2.5/weather?q=vaitape,pf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for vaitape, pf
# http://api.openweathermap.org/data/2.5/weather?q=visby,se&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for visby, se
# http://api.openweathermap.org/data/2.5/weather?q=zheleznodorozhnyy,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for zheleznodorozhnyy, ru
# http://api.openweathermap.org/data/2.5/weather?q=shingu,jp&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for shingu, jp
# http://api.openweathermap.org/data/2.5/weather?q=vila franca do campo,pt&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for vila franca do campo, pt
# http://api.openweathermap.org/data/2.5/weather?q=namatanai,pg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for namatanai, pg
# http://api.openweathermap.org/data/2.5/weather?q=brandon,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for brandon, us
# http://api.openweathermap.org/data/2.5/weather?q=kalianget,id&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kalianget, id
# http://api.openweathermap.org/data/2.5/weather?q=bell ville,ar&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bell ville, ar
# http://api.openweathermap.org/data/2.5/weather?q=shcherbynivka,ua&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for shcherbynivka, ua
# http://api.openweathermap.org/data/2.5/weather?q=kondinskoye,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kondinskoye, ru
# http://api.openweathermap.org/data/2.5/weather?q=candido mendes,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for candido mendes, br
# http://api.openweathermap.org/data/2.5/weather?q=aldan,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for aldan, ru
# http://api.openweathermap.org/data/2.5/weather?q=ponta delgada,pt&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for ponta delgada, pt
# http://api.openweathermap.org/data/2.5/weather?q=zhanaozen,kz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for zhanaozen, kz
# http://api.openweathermap.org/data/2.5/weather?q=tarauaca,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tarauaca, br
# http://api.openweathermap.org/data/2.5/weather?q=kieta,pg&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kieta, pg
# http://api.openweathermap.org/data/2.5/weather?q=nuuk,gl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nuuk, gl
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere,nz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for tuatapere, nz
# http://api.openweathermap.org/data/2.5/weather?q=lakes entrance,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lakes entrance, au
# http://api.openweathermap.org/data/2.5/weather?q=san juan,ar&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for san juan, ar
# http://api.openweathermap.org/data/2.5/weather?q=katsuura,jp&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for katsuura, jp
# http://api.openweathermap.org/data/2.5/weather?q=campbell river,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for campbell river, ca
# http://api.openweathermap.org/data/2.5/weather?q=pueblo nuevo,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for pueblo nuevo, mx
# http://api.openweathermap.org/data/2.5/weather?q=la paz,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for la paz, mx
# http://api.openweathermap.org/data/2.5/weather?q=podor,sn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for podor, sn
# http://api.openweathermap.org/data/2.5/weather?q=bayan,kw&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bayan, kw
# http://api.openweathermap.org/data/2.5/weather?q=bina-etawa,in&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bina-etawa, in
# http://api.openweathermap.org/data/2.5/weather?q=bilibino,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bilibino, ru
# http://api.openweathermap.org/data/2.5/weather?q=evensk,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for evensk, ru
# http://api.openweathermap.org/data/2.5/weather?q=chunar,in&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for chunar, in
# http://api.openweathermap.org/data/2.5/weather?q=maun,bw&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for maun, bw
# http://api.openweathermap.org/data/2.5/weather?q=yeniseysk,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for yeniseysk, ru
# http://api.openweathermap.org/data/2.5/weather?q=homer,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for homer, us
# http://api.openweathermap.org/data/2.5/weather?q=jalu,ly&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for jalu, ly
# http://api.openweathermap.org/data/2.5/weather?q=rodrigues alves,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for rodrigues alves, br
# http://api.openweathermap.org/data/2.5/weather?q=kuybysheve,ua&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kuybysheve, ua
# http://api.openweathermap.org/data/2.5/weather?q=halalo,wf&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# No data for halalo, wf
# http://api.openweathermap.org/data/2.5/weather?q=mildura,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for mildura, au
# http://api.openweathermap.org/data/2.5/weather?q=havre,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for havre, us
# http://api.openweathermap.org/data/2.5/weather?q=hay river,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for hay river, ca
# http://api.openweathermap.org/data/2.5/weather?q=bushenyi,ug&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bushenyi, ug
# http://api.openweathermap.org/data/2.5/weather?q=inverness,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for inverness, ca
# http://api.openweathermap.org/data/2.5/weather?q=saint-joseph,re&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for saint-joseph, re
# http://api.openweathermap.org/data/2.5/weather?q=lima,pe&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lima, pe
# http://api.openweathermap.org/data/2.5/weather?q=behshahr,ir&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for behshahr, ir
# http://api.openweathermap.org/data/2.5/weather?q=kenai,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kenai, us
# http://api.openweathermap.org/data/2.5/weather?q=marawi,sd&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for marawi, sd
# http://api.openweathermap.org/data/2.5/weather?q=kathu,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kathu, za
# http://api.openweathermap.org/data/2.5/weather?q=dakar,sn&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for dakar, sn
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for pangnirtung, ca
# http://api.openweathermap.org/data/2.5/weather?q=broken hill,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for broken hill, au
# http://api.openweathermap.org/data/2.5/weather?q=skagastrond,is&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for skagastrond, is
# http://api.openweathermap.org/data/2.5/weather?q=boyuibe,bo&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for boyuibe, bo
# http://api.openweathermap.org/data/2.5/weather?q=kudahuvadhoo,mv&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for kudahuvadhoo, mv
# http://api.openweathermap.org/data/2.5/weather?q=nelson bay,au&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nelson bay, au
# http://api.openweathermap.org/data/2.5/weather?q=maceio,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for maceio, br
# http://api.openweathermap.org/data/2.5/weather?q=veydelevka,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for veydelevka, ru
# http://api.openweathermap.org/data/2.5/weather?q=wahran,dz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# No data for wahran, dz
# http://api.openweathermap.org/data/2.5/weather?q=pathein,mm&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for pathein, mm
# http://api.openweathermap.org/data/2.5/weather?q=derzhavinsk,kz&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for derzhavinsk, kz
# http://api.openweathermap.org/data/2.5/weather?q=lazaro cardenas,mx&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for lazaro cardenas, mx
# http://api.openweathermap.org/data/2.5/weather?q=nowa ruda,pl&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for nowa ruda, pl
# http://api.openweathermap.org/data/2.5/weather?q=pitimbu,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for pitimbu, br
# http://api.openweathermap.org/data/2.5/weather?q=bayir,jo&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for bayir, jo
# http://api.openweathermap.org/data/2.5/weather?q=chegdomyn,ru&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for chegdomyn, ru
# http://api.openweathermap.org/data/2.5/weather?q=el alto,pe&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for el alto, pe
# http://api.openweathermap.org/data/2.5/weather?q=whittlesea,za&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for whittlesea, za
# http://api.openweathermap.org/data/2.5/weather?q=la ronge,ca&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for la ronge, ca
# http://api.openweathermap.org/data/2.5/weather?q=rio grande,br&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for rio grande, br
# http://api.openweathermap.org/data/2.5/weather?q=carbondale,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for carbondale, us
# http://api.openweathermap.org/data/2.5/weather?q=evanston,us&units=imperial&APPID=862e2d5f1fa11f589a0d6ca0acbd4cdb
# Retrieved data for evanston, us

# %%
location_data.head(20)#check
# Out:
#     lat_values  lng_values              city country   Temp Humidity  \
# 0   -37.772357  -11.362772         jamestown      sh  68.08      100
# 1    88.400137 -172.652405       mys shmidta      ru   26.6      100
# 2   -48.354058   -3.086240         cape town      za     50       76
# 3    44.725651  -62.494576       new glasgow      ca  51.07       86
# 4    47.626344  -54.124985       bay roberts      ca     41       86
# 5    69.445506  -89.180829          thompson      ca     32       76
# 6    18.187079  -45.324629         sinnamary      gf  80.95       95
# 7   -39.381647  -23.011323   arraial do cabo      br   75.2       88
# 8   -37.550420  101.131880         busselton      au  63.94      100
# 9   -40.371505 -137.027571           rikitea      pf  72.58      100
# 10    5.428431 -101.469966  puerto escondido      mx   84.2       74
# 11  -53.072388 -167.263954            avarua      ck  73.93      100
# 12   33.704201  147.559510            hasaki      jp  58.87       82
# 13   54.582906  103.280250           ust-uda      ru  25.15      100
# 15   23.386876  109.632133          guicheng      cn  67.72       81
# 16  -72.087338 -174.007741             vaini      to   80.6       83
# 17  -30.277840  -97.508074              lebu      cl   52.6      100
# 18    1.981097  -40.776823           camocim      br  80.09       72
# 19   11.248502    8.090498             zaria      ng  60.34       52
# 20  -30.424333  174.323193              kaeo      nz  67.72       64
#
#    Cloudiness Wind Speed    Lat Longitude
# 0          88      16.06 -15.94     -5.72
# 1          90       8.95  52.98     49.71
# 2           0       2.24 -33.93     18.42
# 3           0       7.11  45.58    -62.65
# 4          90       6.93   47.6    -53.26
# 5          90       3.36  55.74    -97.86
# 6          64      11.03   5.38    -52.95
# 7          75      13.87 -22.97    -42.03
# 8           8      24.94 -33.65    115.33
# 9           8       7.49 -23.12   -134.97
# 10         75      11.41  15.85    -97.07
# 11         12      14.43 -21.21   -159.78
# 12         75       9.17  35.73    140.83
# 13         64       4.09  54.17    103.03
# 15          0       2.46   23.1    109.61
# 16         75        4.7  -21.2    -175.2
# 17         76       6.78 -37.62    -73.65
# 18          0      18.01   -2.9    -40.84
# 19         20        2.8  11.11      7.72
# 20         56       7.78  -35.1    173.78

# %%
# check the total sample size.
len(location_data)
# Out:
# 606

# %%
# Save the DataFrame as a csv
location_data.to_csv("weatherpy_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# Used Pandas to change string values to numerics for plotting

# %%
location_data['Lat'] = pd.to_numeric(location_data['Lat'], errors = 'coerce')
location_data['Temp'] = pd.to_numeric(location_data['Temp'], errors = 'coerce')
location_data['Humidity'] = pd.to_numeric(location_data['Humidity'], errors = 'coerce')
location_data['Wind Speed'] = pd.to_numeric(location_data['Wind Speed'], errors = 'coerce')
location_data['Cloudiness'] = pd.to_numeric(location_data['Cloudiness'], errors = 'coerce')

# %%
location_data.head()
# Out:
#    lat_values  lng_values         city country   Temp  Humidity  Cloudiness  \
# 0  -37.772357  -11.362772    jamestown      sh  68.08     100.0        88.0
# 1   88.400137 -172.652405  mys shmidta      ru  26.60     100.0        90.0
# 2  -48.354058   -3.086240    cape town      za  50.00      76.0         0.0
# 3   44.725651  -62.494576  new glasgow      ca  51.07      86.0         0.0
# 4   47.626344  -54.124985  bay roberts      ca  41.00      86.0        90.0
#
#    Wind Speed    Lat Longitude
# 0       16.06 -15.94     -5.72
# 1        8.95  52.98     49.71
# 2        2.24 -33.93     18.42
# 3        7.11  45.58    -62.65
# 4        6.93  47.60    -53.26

# %% [markdown]
# Plots
# Temperature Vs. Latitude

# %%
x= location_data["Lat"]
y= location_data["Temp"]
plt.scatter (x,y, edgecolor = 'black')
plt.title('Temperature (F) vs. Latitude')
plt.ylabel("Temperature (F)")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# Humidity (%) vs. Latitude

# %%
x= location_data["Lat"]
y= location_data["Humidity"]
plt.scatter (x,y,edgecolor = 'black')
plt.title('Humidity (%) vs. Latitude')
plt.ylabel("Humidity (%)")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# Cloudiness (%) vs. Latitude

# %%
x= location_data["Lat"]
y= location_data["Cloudiness"]
plt.scatter (x,y,edgecolor = 'black')
plt.title('Cloudiness (%) vs. Latitude')
plt.ylabel("Cloudiness (%)")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# Wind Speed (mph) vs. Latitude

# %%
x= location_data["Lat"]
y= location_data["Wind Speed"]
plt.scatter (x,y, edgecolor = 'black')
plt.title('Wind Speed (mph) vs. Latitude')
plt.ylabel("Wind Speed (mph)")
plt.xlabel('Latitude')
plt.show()
